# %%
from mikeio import Mesh
import numpy as np

mesh_path = r"D:\Phd Research\Prototype HD Model\Mesh File\prototype_domain_utm_corrected_mesh_for_100yr.mesh"

m = Mesh(mesh_path)
n_nodes = int(m.n_nodes)
n_elems = int(m.n_elements)
print(n_elems)
print(n_nodes)
# Out:
# 202643
# 101617
