# %%
import matplotlib.pyplot as plt

# Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
quantile_17 = [0.10, 0.17, 0.26, 0.35, 0.45, 0.54, 0.64, 0.73, 0.81, 0.87, 0.96, 1.05, 1.13, 1.22]
median_50 = [0.13, 0.22, 0.33, 0.44, 0.54, 0.65, 0.77, 0.88, 1.00, 1.11, 1.23, 1.35, 1.47, 1.59]
quantile_83 = [0.16, 0.27, 0.40, 0.53, 0.66, 0.80, 0.95, 1.10, 1.26, 1.43, 1.60, 1.76, 1.92, 2.08]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(years, quantile_17, label="17th Quantile", linestyle='dashed', marker='o')
plt.plot(years, median_50, label="50th Median", linestyle='solid', marker='s')
plt.plot(years, quantile_83, label="83rd Quantile", linestyle='dotted', marker='^')

# Labels and title
plt.xlabel("Year")
plt.ylabel("Sea Level Rise (m)")
plt.title("Sea Level Rise Projection")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
quantile_17 = [0.10, 0.17, 0.26, 0.35, 0.45, 0.54, 0.64, 0.73, 0.81, 0.87, 0.96, 1.05, 1.13, 1.22]
median_50 = [0.13, 0.22, 0.33, 0.44, 0.54, 0.65, 0.77, 0.88, 1.00, 1.11, 1.23, 1.35, 1.47, 1.59]
quantile_83 = [0.16, 0.27, 0.40, 0.53, 0.66, 0.80, 0.95, 1.10, 1.26, 1.43, 1.60, 1.76, 1.92, 2.08]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(years, median_50, label="50th Median", linestyle='solid', color='blue', marker='s')
plt.fill_between(years, quantile_17, quantile_83, color='blue', alpha=0.2, label="17th - 83rd Quantile Range")

# Vertical line at 2100
plt.axvline(x=2100, color='red', linestyle='dashed', label="SLR in 2100")

# Labels and title
plt.xlabel("Year")
plt.ylabel("Sea Level Rise (m)")
plt.title("Sea Level Rise Projection")
plt.legend(loc='upper left')  # Legend position in upper left corner
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
quantile_17 = [0.10, 0.17, 0.26, 0.35, 0.45, 0.54, 0.64, 0.73, 0.81, 0.87, 0.96, 1.05, 1.13, 1.22]
median_50 = [0.13, 0.22, 0.33, 0.44, 0.54, 0.65, 0.77, 0.88, 1.00, 1.11, 1.23, 1.35, 1.47, 1.59]
quantile_83 = [0.16, 0.27, 0.40, 0.53, 0.66, 0.80, 0.95, 1.10, 1.26, 1.43, 1.60, 1.76, 1.92, 2.08]

# Extract SLR for 2100
year_2100 = 2100
slr_2100_median = median_50[years.index(year_2100)]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(years, median_50, label="50th Median", linestyle='solid', color='blue', marker='s')
plt.fill_between(years, quantile_17, quantile_83, color='blue', alpha=0.2, label="17th - 83rd Quantile Range")

# Vertical dashed line at 2100 reaching the SLR value
plt.axvline(x=year_2100, ymin=0, ymax=slr_2100_median/2.5, color='red', linestyle='dashed', label="SLR in 2100")

# Horizontal dashed line extending to y-axis
plt.axhline(y=slr_2100_median, xmin=0.05, xmax=0.65, color='red', linestyle='dashed')

# Annotate the SLR value at 2100
plt.text(year_2100 - 8, slr_2100_median + 0.05, f"{slr_2100_median:.2f} m", color='red', fontsize=12)

# Labels and title
plt.xlabel("Year")
plt.ylabel("Sea Level Rise (m)")
plt.title("Sea Level Rise Projection")
plt.legend(loc='upper left')  # Legend in the upper left corner
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
quantile_17 = [0.10, 0.17, 0.26, 0.35, 0.45, 0.54, 0.64, 0.73, 0.81, 0.87, 0.96, 1.05, 1.13, 1.22]
median_50 = [0.13, 0.22, 0.33, 0.44, 0.54, 0.65, 0.77, 0.88, 1.00, 1.11, 1.23, 1.35, 1.47, 1.59]
quantile_83 = [0.16, 0.27, 0.40, 0.53, 0.66, 0.80, 0.95, 1.10, 1.26, 1.43, 1.60, 1.76, 1.92, 2.08]

# Extract SLR for 2100
year_2100 = 2100
slr_2100_median = median_50[years.index(year_2100)]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(years, median_50, label="50th Median", linestyle='solid', color='blue', )
plt.fill_between(years, quantile_17, quantile_83, color='blue', alpha=0.2, label="17th - 83rd Quantile Range")

# Dashed red line: vertical from x-axis to 50th median at 2100
plt.plot([year_2100, year_2100], [0, slr_2100_median], 'r--', label="SLR in 2100")

# Dashed red line: horizontal from intersection to y-axis
plt.plot([2020, year_2100], [slr_2100_median, slr_2100_median], 'r--')

# Annotate the SLR value at 2100
plt.text(year_2100 - 15, slr_2100_median + 0.05, f"{slr_2100_median:.2f} m", color='red', fontsize=12)

# Labels and title
plt.xlabel("Year")
plt.ylabel("Sea Level Rise (m)")
plt.title("Sea Level Rise Projection")
plt.legend(loc='upper left')  # Legend in the upper left corner
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
quantile_17 = [0.10, 0.17, 0.26, 0.35, 0.45, 0.54, 0.64, 0.73, 0.81, 0.87, 0.96, 1.05, 1.13, 1.22]
median_50 = [0.13, 0.22, 0.33, 0.44, 0.54, 0.65, 0.77, 0.88, 1.00, 1.11, 1.23, 1.35, 1.47, 1.59]
quantile_83 = [0.16, 0.27, 0.40, 0.53, 0.66, 0.80, 0.95, 1.10, 1.26, 1.43, 1.60, 1.76, 1.92, 2.08]

# Extract SLR for 2100
year_2100 = 2100
slr_2100_median = median_50[years.index(year_2100)]

# Plot
plt.figure(figsize=(8, 4.5))
plt.plot(years, median_50, label="50th Median", linestyle='solid', color='blue')
plt.fill_between(years, quantile_17, quantile_83, color='blue', alpha=0.2, label="17th - 83rd Quantile Range")

# Dashed red line: vertical (from x-axis at 2100 to the SLR value)
plt.axvline(x=year_2100, ymin=0, ymax=(slr_2100_median / max(quantile_83)), color='red', linestyle='dashed')

# Dashed red line: horizontal (from y-axis to 2100 SLR value)
plt.axhline(y=slr_2100_median, xmin=0, xmax=((year_2100 - min(years)) / (max(years) - min(years))), color='red', linestyle='dashed')

# Label the intersection
plt.text(year_2100 + 2, slr_2100_median, f"{slr_2100_median:.2f} m", color='red', fontsize=14, verticalalignment='bottom')

# Labels and title
plt.xlabel("Year",fontsize=16)
plt.ylabel("Sea Level Rise (m)",fontsize=16)
plt.title("Sea Level Rise Projection",fontsize=16)
plt.legend(loc='upper left',fontsize=14)  # Legend in the upper left corner
# Tick parameters
plt.tick_params(axis='both', which='major', labelsize=14)
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
quantile_17 = [0.10, 0.17, 0.26, 0.35, 0.45, 0.54, 0.64, 0.73, 0.81, 0.87, 0.96, 1.05, 1.13, 1.22]
median_50 = [0.13, 0.22, 0.33, 0.44, 0.54, 0.65, 0.77, 0.88, 1.00, 1.11, 1.23, 1.35, 1.47, 1.59]
quantile_83 = [0.16, 0.27, 0.40, 0.53, 0.66, 0.80, 0.95, 1.10, 1.26, 1.43, 1.60, 1.76, 1.92, 2.08]

# Extract SLR for 2100
year_2100 = 2100
slr_2100_median = median_50[years.index(year_2100)]

# Plot
plt.figure(figsize=(8, 4.5))
plt.plot(years, median_50, label="50th Median", linestyle='solid', color='blue')
plt.fill_between(years, quantile_17, quantile_83, color='blue', alpha=0.2, label="17th - 83rd Quantile Range")

# Dashed red line: vertical (from x-axis at 2100 to the SLR value)
plt.axvline(x=year_2100, ymin=0, ymax=(slr_2100_median / max(quantile_83)), color='red', linestyle='dashed')

# Dashed red line: horizontal (from y-axis to 2100 SLR value)
plt.axhline(y=slr_2100_median, xmin=0, xmax=((year_2100 - min(years)) / (max(years) - min(years))), color='red', linestyle='dashed')

# Label the intersection
# plt.text(year_2100 + 2, slr_2100_median, f"{slr_2100_median:.2f} m", color='red', fontsize=14, verticalalignment='bottom')

# Labels and title
# plt.xlabel("Year",fontsize=16)
# plt.ylabel("Sea Level Rise (m)",fontsize=16)
# plt.title("Sea Level Rise Projection",fontsize=16)
plt.legend(loc='upper left',fontsize=14)  # Legend in the upper left corner
# Tick parameters
plt.tick_params(axis='both', which='major', labelsize=14)
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Updated Vertical Land Motion (VLM) Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
vlm = [0.0000, 0.0169, 0.0338, 0.0507, 0.0676, 0.0845, 0.1014, 0.1183, 0.1352, 
       0.1521, 0.1690, 0.1859, 0.2028, 0.2197]

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(years, vlm, linestyle='solid', color='blue', marker='o', label="VLM (m)")

# Labels and title
plt.xlabel("Year")
plt.ylabel("Vertical Land Motion (m)")
plt.title("Vertical Land Motion Projection")
plt.legend(loc='upper left')  # Legend in the upper left corner
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Vertical Land Motion (VLM) Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
vlm = [0.0000, 0.0169, 0.0338, 0.0507, 0.0676, 0.0845, 0.1014, 0.1183, 0.1352, 
       0.1521, 0.1690, 0.1859, 0.2028, 0.2197]

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(years, vlm, linestyle='solid', color='blue', marker='o', label="VLM (m)")

# Add a dashed red vertical line at 2100
plt.axvline(x=2100, ymin=0, ymax=(vlm[8] / max(vlm)), linestyle='dashed', color='red', linewidth=2)

# Add horizontal extension to Y-axis
plt.axhline(y=vlm[8], xmin=0, xmax=((2100 - 2020) / (2150 - 2020)), linestyle='dashed', color='red', linewidth=2)

# Labels and title
plt.xlabel("Year")
plt.ylabel("Vertical Land Motion (m)")
plt.title("Vertical Land Motion Projection")
plt.legend(loc='upper left')  # Legend in the upper left corner
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Vertical Land Motion (VLM) Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
vlm = [0.0000, 0.0169, 0.0338, 0.0507, 0.0676, 0.0845, 0.1014, 0.1183, 0.1352, 
       0.1521, 0.1690, 0.1859, 0.2028, 0.2197]

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(years, vlm, linestyle='solid', color='blue',  label="VLM (m)")

# Year 2100 VLM value
year_2100 = 2100
vlm_2100 = vlm[8]  # Corresponding VLM value for 2100

# Add a dashed red vertical line at 2100
plt.axvline(x=year_2100, ymin=0, ymax=(vlm_2100 / max(vlm)), linestyle='dashed', color='red', linewidth=2)

# Add horizontal extension to Y-axis
plt.axhline(y=vlm_2100, xmin=0, xmax=((year_2100 - 2020) / (2150 - 2020)), linestyle='dashed', color='red', linewidth=2)

# Add text annotation for VLM value
plt.text(year_2100 + 2, vlm_2100, f"{vlm_2100:.2f} m", color='red', fontsize=12, verticalalignment='bottom')

# Labels and title
plt.xlabel("Year",fontsize=14)
plt.ylabel("Vertical Land Motion (m)",fontsize=14)
plt.title("Vertical Land Motion Projection")
plt.legend(loc='upper left')  # Legend in the upper left corner
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Vertical Land Motion (VLM) Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
vlm = [0.0000, 0.0169, 0.0338, 0.0507, 0.0676, 0.0845, 0.1014, 0.1183, 0.1352, 
       0.1521, 0.1690, 0.1859, 0.2028, 0.2197]

# Create the plot
plt.figure(figsize=(8, 4.5))
plt.plot(years, vlm, linestyle='solid', color='blue', label="VLM (m)", linewidth=2)

# Year 2100 VLM value
year_2100 = 2100
vlm_2100 = vlm[8]

# Add a dashed red vertical line at 2100
plt.axvline(x=year_2100, ymin=0, ymax=(vlm_2100 / max(vlm)), linestyle='dashed', color='red', linewidth=2)

# Add horizontal extension to Y-axis
plt.axhline(y=vlm_2100, xmin=0, xmax=((year_2100 - 2020) / (2150 - 2020)), linestyle='dashed', color='red', linewidth=2)

# Add text annotation for VLM value
plt.text(year_2100 + 2, vlm_2100, f"{vlm_2100:.2f} m", color='red', fontsize=14, verticalalignment='bottom')

# Labels and title
plt.xlabel("Year", fontsize=16)
plt.ylabel("Vertical Land Motion (m)", fontsize=16)
plt.title("Vertical Land Motion Projection", fontsize=18)

# Tick parameters
plt.tick_params(axis='both', which='major', labelsize=14)

# Legend
plt.legend(loc='upper left', fontsize=14)

# Grid
plt.grid(True)

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Vertical Land Motion (VLM) Data
years = [2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100, 2110, 2120, 2130, 2140, 2150]
vlm = [0.0000, 0.0169, 0.0338, 0.0507, 0.0676, 0.0845, 0.1014, 0.1183, 0.1352, 
       0.1521, 0.1690, 0.1859, 0.2028, 0.2197]

# Create the plot
plt.figure(figsize=(8, 4.5))
plt.plot(years, vlm, linestyle='solid', color='blue', label="VLM (m)", linewidth=2)

# Year 2100 VLM value
year_2100 = 2100
vlm_2100 = vlm[8]

# Add a dashed red vertical line at 2100
plt.axvline(x=year_2100, ymin=0, ymax=(vlm_2100 / max(vlm)), linestyle='dashed', color='red', linewidth=2)

# Add horizontal extension to Y-axis
plt.axhline(y=vlm_2100, xmin=0, xmax=((year_2100 - 2020) / (2150 - 2020)), linestyle='dashed', color='red', linewidth=2)

# Add text annotation for VLM value
#plt.text(year_2100 + 2, vlm_2100, f"{vlm_2100:.2f} m", color='red', fontsize=14, verticalalignment='bottom')

# Labels and title
# plt.xlabel("Year", fontsize=16)
# plt.ylabel("Vertical Land Motion (m)", fontsize=16)
# plt.title("Vertical Land Motion Projection", fontsize=18)

# Tick parameters
plt.tick_params(axis='both', which='major', labelsize=14)

# Legend
plt.legend(loc='upper left', fontsize=14)

# Grid
plt.grid(True)

# Show plot
plt.tight_layout()
plt.show()
