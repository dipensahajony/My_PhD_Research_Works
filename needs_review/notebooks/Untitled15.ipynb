# %%
import numpy as np
import pandas as pd
import xarray as xr
import mikeio
from matplotlib import pyplot as plt

ds = xr.open_dataset(r"D:\Phd Research\Data\Wave Data\adaptor.mars.internal-1720732216.0323093-8696-14-55994bcf-d128-46ab-ada8-77b180bb6c62.nc")
ds
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:    (longitude: 7, latitude: 6, time: 1488)
# Coordinates:
#   * longitude  (longitude) float32 28B -97.64 -97.14 -96.64 ... -95.14 -94.64
#   * latitude   (latitude) float32 24B 28.62 28.12 27.62 27.12 26.62 26.12
#   * time       (time) datetime64[ns] 12kB 2017-07-01 ... 2017-08-31T23:00:00
# Data variables:
#     mwd        (time, latitude, longitude) float64 500kB ...
#     mwp        (time, latitude, longitude) float64 500kB ...
#     pp1d       (time, latitude, longitude) float64 500kB ...
#     swh        (time, latitude, longitude) float64 500kB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-07-11 21:10:26 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
ds_aoi = ds.sel(longitude=slice(-97,-94), 
                latitude=slice(29,26)) # N -> S
ds_aoi
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:    (longitude: 5, latitude: 6, time: 1488)
# Coordinates:
#   * longitude  (longitude) float32 20B -96.64 -96.14 -95.64 -95.14 -94.64
#   * latitude   (latitude) float32 24B 28.62 28.12 27.62 27.12 26.62 26.12
#   * time       (time) datetime64[ns] 12kB 2017-07-01 ... 2017-08-31T23:00:00
# Data variables:
#     mwd        (time, latitude, longitude) float64 357kB ...
#     mwp        (time, latitude, longitude) float64 357kB ...
#     pp1d       (time, latitude, longitude) float64 357kB ...
#     swh        (time, latitude, longitude) float64 357kB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-07-11 21:10:26 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
ds_aoi.isel(time=0).swh.plot()
