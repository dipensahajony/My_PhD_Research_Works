# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample data
data = {
    'County': ["Kenedy", "Kleberg", "Matagorda", "Nueces", "Refugio", "San Patricio", 
               "Victoria", "Wharton", "Aransas", "Bee", "Brazoria", "Calhoun", 
               "Jackson", "Jim Wells", "Willacy", "Brooks"],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 
                 0.3293, 0.3794, 0.622322, 0.668765, 0.5749, 0.724404, 
                 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

df = pd.DataFrame(data)

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(15, 10))

# Define positions and width for bars
width = 0.2
x = np.arange(len(df['County']))

# Plotting bars for each return period
ax.bar(x - 1.5 * width, df['5 yr'], width, label='5 yr', color='blue', alpha=0.7)
ax.bar(x - 0.5 * width, df['10 yr'], width, label='10 yr', color='green', alpha=0.7)
ax.bar(x + 0.5 * width, df['20 yr'], width, label='20 yr', color='orange', alpha=0.7)
ax.bar(x + 1.5 * width, df['50 yr'], width, label='50 yr', color='red', alpha=0.7)

# Adding SVI as annotations above the bars
for i in range(len(df)):
    ax.text(x[i], max(df.loc[i, ['5 yr', '10 yr', '20 yr', '50 yr']]) + 5000, 
            f'SVI: {df["Avg. SVI"][i]:.2f}', ha='center', color='black', fontsize=12)

# Labels and title
ax.set_xlabel('County', fontsize=20)
ax.set_ylabel('Flood Affected Population', fontsize=20)
# ax.set_title('Flood Affected Population by County for Different Return Periods', fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(df['County'], rotation=45, ha='right', fontsize=20)
ax.tick_params(axis='y', labelsize=20)  # Set y-axis tick label size
ax.legend( fontsize=20)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Reshape the DataFrame for the heatmap
df_melted = df.melt(id_vars=['County', 'Avg. SVI'], var_name='Return Period', value_name='Flood Affected Population')

# Pivot to get the heatmap format
heatmap_data = df_melted.pivot('County', 'Return Period', 'Flood Affected Population')

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlOrRd", cbar_kws={'label': 'Flood Affected Population'})
plt.title('Flood Affected Population by County and Return Period')
plt.xlabel('Return Period')
plt.ylabel('County')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Reshape the DataFrame for the heatmap
df_melted = df.melt(id_vars=['County', 'Avg. SVI'], var_name='Return Period', value_name='Flood Affected Population')

# Pivot with specific order for the return period columns
heatmap_data = df_melted.pivot('County', 'Return Period', 'Flood Affected Population')
heatmap_data = heatmap_data[['5 yr', '10 yr', '20 yr', '50 yr']]  # Ensure correct order

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlOrRd", cbar_kws={'label': 'Flood Affected Population'})
plt.title('Flood Affected Population by County and Return Period')
plt.xlabel('Return Period')
plt.ylabel('County')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample Data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Reshape the DataFrame for plotting
df_melted = df.melt(id_vars=['County', 'Avg. SVI'], var_name='Return Period', value_name='Flood Affected Population')

# Map return periods to colors for the bubble chart
color_map = {
    '5 yr': 'blue',
    '10 yr': 'green',
    '20 yr': 'orange',
    '50 yr': 'red'
}
df_melted['Color'] = df_melted['Return Period'].map(color_map)

# Plot
plt.figure(figsize=(14, 10))

# Create the bubble plot
for _, row in df_melted.iterrows():
    plt.scatter(row['Return Period'], row['County'], 
                s=row['Flood Affected Population'] / 500,  # Adjust size for visibility
                color=row['Color'], alpha=0.6, edgecolors='w', linewidth=0.5)

# Add legend for return periods
for period, color in color_map.items():
    plt.scatter([], [], color=color, alpha=0.6, s=100, label=period)

plt.legend(title="Return Period")
plt.title("Flood Affected Population by County and Return Period")
plt.xlabel("Return Period")
plt.ylabel("County")
plt.xticks(rotation=45)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Sample Data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Select a county to plot
county_name = "Nueces"
county_data = df[df['County'] == county_name].iloc[0, 1:].values

# Define number of variables (i.e., the return periods)
categories = ['5 yr', '10 yr', '20 yr', '50 yr']
N = len(categories)

# Create the radar chart
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]  # Complete the circle

# Initialize the plot
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plot each return period and close the circle
ax.plot(angles, np.append(county_data, county_data[0]), linewidth=2, linestyle='solid', label=county_name)
ax.fill(angles, np.append(county_data, county_data[0]), color='blue', alpha=0.25)

# Add labels for each axis
plt.xticks(angles[:-1], categories, color='grey', size=12)

# Set the title and legend
plt.title(f'Flood Affected Population for {county_name}', size=15, color='darkblue', y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 
               'Aransas', 'Bee', 'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert data into a DataFrame
df = pd.DataFrame(data)

# Prepare the data for plotting
counties = df['County']
years = ['5 yr', '10 yr', '20 yr', '50 yr']
populations = df[years].T  # Transpose for stacking

# Plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot stacked area chart
ax.stackplot(counties, populations, labels=years, alpha=0.8)

# Add labels, legend, and title
ax.set_title('Flood Affected Population by Return Period for Each County', fontsize=16)
ax.set_xlabel('County', fontsize=12)
ax.set_ylabel('Flood Affected Population', fontsize=12)
ax.legend(title="Return Period", loc='upper left', fontsize=10)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 
               'Aransas', 'Bee', 'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert data into a DataFrame
df = pd.DataFrame(data)
df.set_index('County', inplace=True)

# Prepare the data for plotting
return_periods = ['5 yr', '10 yr', '20 yr', '50 yr']

# Plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot each county as a separate line
for county in df.index:
    ax.plot(return_periods, df.loc[county, return_periods], marker='o', label=county)

# Add labels, legend, and title
ax.set_title('Flood Affected Population Across Return Periods by County', fontsize=16)
ax.set_xlabel('Return Period', fontsize=12)
ax.set_ylabel('Flood Affected Population', fontsize=12)
ax.legend(title="County", loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=10)

# Show the plot with tight layout for better spacing
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Reshape the DataFrame for the heatmap
df_melted = df.melt(id_vars=['County', 'Avg. SVI'], var_name='Return Period', value_name='Flood Affected Population')

# Pivot with specific order for the return period columns
heatmap_data = df_melted.pivot('County', 'Return Period', 'Flood Affected Population')
heatmap_data = heatmap_data[['5 yr', '10 yr', '20 yr', '50 yr']]  # Ensure correct order

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlOrRd", cbar_kws={'label': 'Flood Affected Population'})

# Increase text sizes
plt.title('Flood Affected Population by County and Return Period', fontsize=18)
plt.xlabel('Return Period', fontsize=14)
plt.ylabel('County', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Reshape the DataFrame for the heatmap
df_melted = df.melt(id_vars=['County', 'Avg. SVI'], var_name='Return Period', value_name='Flood Affected Population')

# Pivot with specific order for the return period columns
heatmap_data = df_melted.pivot('County', 'Return Period', 'Flood Affected Population')
heatmap_data = heatmap_data[['5 yr', '10 yr', '20 yr', '50 yr']]  # Ensure correct order

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="YlOrRd", cbar_kws={'label': 'Flood Affected Population'}, annot_kws={'size': 16})

# Increase text sizes
plt.title('Flood Affected Population by County and Return Period', fontsize=18)
plt.xlabel('Return Period', fontsize=16)
plt.ylabel('County', fontsize=16)
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)

# Increase the font size for the color bar (legend)
cbar = plt.gca().collections[0].colorbar
cbar.ax.tick_params(labelsize=14)
cbar.set_label('Flood Affected Population', fontsize=16)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
import matplotlib.colors as mcolors

# Data
counties = ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 
            'Wharton', 'Aransas', 'Bee', 'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 
            'Willacy', 'Brooks']
svi_values = [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 
              0.622322, 0.668765, 0.5749, 0.724404, 0.550436, 0.7199, 0.0, 0.913826]

# Sorting counties based on SVI values (from highest to lowest)
sorted_indices = np.argsort(svi_values)[::-1]
sorted_counties = np.array(counties)[sorted_indices]
sorted_svi_values = np.array(svi_values)[sorted_indices]

# Normalize SVI values to map them to color scale
norm = mcolors.Normalize(vmin=min(svi_values), vmax=max(svi_values))
cmap = cm.viridis

# Plot
plt.figure(figsize=(10, 6))
bars = plt.barh(sorted_counties, sorted_svi_values, color=cmap(norm(sorted_svi_values)))

# Add labels and title
plt.xlabel('Average SVI', fontsize=12)
plt.title('Average Social Vulnerability Index (SVI) by County', fontsize=14)
plt.xticks(np.arange(0, 1.1, 0.1))
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Create and display the colorbar
cbar = plt.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap))
cbar.set_label('SVI', rotation=270, labelpad=15)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39552\700295209.py in <cell line: 33>()
#      31
#      32 # Create and display the colorbar
# ---> 33 cbar = plt.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap))
#      34 cbar.set_label('SVI', rotation=270, labelpad=15)
#      35
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kwargs)
#    2051                                'an image (with imshow) or a contour set ('
#    2052                                'with contourf).')
# -> 2053     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2054     return ret
#    2055
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
import matplotlib.colors as mcolors

# Data
counties = ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 
            'Wharton', 'Aransas', 'Bee', 'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 
            'Willacy', 'Brooks']
svi_values = [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 
              0.622322, 0.668765, 0.5749, 0.724404, 0.550436, 0.7199, 0.0, 0.913826]

# Sorting counties based on SVI values (from highest to lowest)
sorted_indices = np.argsort(svi_values)[::-1]
sorted_counties = np.array(counties)[sorted_indices]
sorted_svi_values = np.array(svi_values)[sorted_indices]

# Normalize SVI values to map them to color scale
norm = mcolors.Normalize(vmin=min(svi_values), vmax=max(svi_values))
cmap = cm.plasma

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(sorted_counties, sorted_svi_values, color=cmap(norm(sorted_svi_values)))

# Add labels and title
ax.set_ylabel('Average SVI', fontsize=12)
ax.set_title('Average Social Vulnerability Index (SVI) by County', fontsize=14)
ax.set_xticklabels(sorted_counties, rotation=45, ha='right', fontsize=10)
ax.set_yticks(np.arange(0, 1.1, 0.1), fontsize=10)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Create and display the colorbar
cbar = fig.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax)
cbar.set_label('SVI', rotation=270, labelpad=15)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sahad2\AppData\Local\Temp\ipykernel_39552\2454690928.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sorted_counties, rotation=45, ha='right', fontsize=10)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set font sizes for all elements
plt.rcParams.update({
    'axes.titlesize': 16,
    'axes.labelsize': 16,
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'legend.fontsize': 16,
    'figure.titlesize': 18
})

# Data
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
approaches = ['Processed Based', 'Bathtub approach']
data = {
    'School': {
        'Processed Based': [(86, 85), (138, 33), (153, 18), (168, 3)],
        'Bathtub approach': [(109, 62), (132, 39), (143, 28), (160, 11)]
    },
    'Hospital': {
        'Processed Based': [(9, 13), (11, 11), (12, 10), (19, 3)],
        'Bathtub approach': [(6, 16), (10, 12), (12, 10), (18, 4)]
    },
    'Fire and EMS': {
        'Processed Based': [(34, 28), (47, 15), (53, 9), (58, 4)],
        'Bathtub approach': [(32, 30), (45, 17), (48, 14), (54, 8)]
    },
    'National Shelter': {
        'Processed Based': [(16, 31), (37, 10), (42, 5), (43, 4)],
        'Bathtub approach': [(28, 19), (36, 11), (40, 7), (44, 3)]
    }
}

# Plot function
def plot_flood_data(data, return_periods):
    categories = list(data.keys())
    fig, axes = plt.subplots(2, 2, figsize=(15, 10), sharey=True)
    axes = axes.flatten()
    
    for i, category in enumerate(categories):
        ax = axes[i]
        
        x = np.arange(len(return_periods))
        width = 0.2

        # Extract data
        fa_p = [data[category]['Processed Based'][j][0] for j in range(len(return_periods))]
        fs_p = [data[category]['Processed Based'][j][1] for j in range(len(return_periods))]
        fa_b = [data[category]['Bathtub approach'][j][0] for j in range(len(return_periods))]
        fs_b = [data[category]['Bathtub approach'][j][1] for j in range(len(return_periods))]

        # Plot
        ax.bar(x - width, fa_p, width, color='skyblue', label='Flood Affected (Processed)')
        ax.bar(x, fs_p, width, color='blue', label='Flood Safe (Processed)')
        ax.bar(x + width, fa_b, width, color='lightcoral', label='Flood Affected (Bathtub)')
        ax.bar(x + 2 * width, fs_b, width, color='darkred', label='Flood Safe (Bathtub)')

        ax.set_title(f'{category}')
        ax.set_xticks(x + width / 2)
        ax.set_xticklabels(return_periods)
        ax.set_xlabel('Return Period')
        ax.set_ylabel('Count')

        # Add legend only to the second subplot (index 1)
        if i == 1:
            ax.legend(loc='upper left')

    plt.tight_layout()
    #plt.suptitle('Flood Impact on Different Infrastructures')
    plt.subplots_adjust(top=0.93)
    plt.show()

# Run the function
plot_flood_data(data, return_periods)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set font sizes for a more readable plot
plt.rcParams.update({
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16
})

# Data extracted from the table
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
approaches = ['Processed Based', 'Bathtub approach']

# Data structure: [Flood affected, Flood Safe] for each category in each approach
data = {
    'School': {
        'Processed Based': [(86, 85), (138, 33), (153, 18), (168, 3)],
        'Bathtub approach': [(109, 62), (132, 39), (143, 28), (160, 11)]
    },
    'Hospital': {
        'Processed Based': [(9, 13), (11, 11), (12, 10), (19, 3)],
        'Bathtub approach': [(6, 16), (10, 12), (12, 10), (18, 4)]
    },
    'Fire and EMS': {
        'Processed Based': [(34, 28), (47, 15), (53, 9), (58, 4)],
        'Bathtub approach': [(32, 30), (45, 17), (48, 14), (54, 8)]
    },
    'National Shelter': {
        'Processed Based': [(16, 31), (37, 10), (42, 5), (43, 4)],
        'Bathtub approach': [(28, 19), (36, 11), (40, 7), (44, 3)]
    }
}

# Function to plot the data
def plot_flood_data(data, return_periods):
    categories = data.keys()
    fig, axes = plt.subplots(2, 2, figsize=(16, 12), sharey=True)
    axes = axes.flatten()
    
    for i, category in enumerate(categories):
        ax = axes[i]
        
        # Retrieve data for each return period and approach
        flood_affected_processed = [data[category]['Processed Based'][j][0] for j in range(len(return_periods))]
        flood_affected_bathtub = [data[category]['Bathtub approach'][j][0] for j in range(len(return_periods))]
        
        # Calculate the difference between bathtub and processed for flood affected counts
        difference = np.array(flood_affected_bathtub) - np.array(flood_affected_processed)
        
        # X-axis positions for groups
        x = np.arange(len(return_periods))
        width = 0.35  # Bar width
        
        # Plotting the data
        ax.bar(x - width/2, flood_affected_processed, width, label='Processed Based', color='skyblue')
        ax.bar(x + width/2, flood_affected_bathtub, width, label='Bathtub approach', color='lightcoral')
        
        # Line plot for differences
        ax.plot(x, difference, color='green', marker='o', linestyle='--', label='Difference (Bathtub - Processed)')
        
        # Color the line points based on positive (overestimate) or negative (underestimate)
        for j in range(len(difference)):
            color = 'red' if difference[j] > 0 else 'blue'
            ax.plot(x[j], difference[j], marker='o', color=color)
        
        # Customize plot
        ax.set_title(f'{category}')
        ax.set_xticks(x)
        ax.set_xticklabels(return_periods)
        ax.set_xlabel('Return Period')
        ax.set_ylabel('Flood Affected Count')
        ax.legend(loc='upper left')
    
    plt.tight_layout()
#     plt.suptitle('Comparison of Flood Affected Counts: Bathtub vs Processed Approach')
    plt.subplots_adjust(top=0.92)  # Adjust title positioning
    plt.show()

# Run the plotting function
plot_flood_data(data, return_periods)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
processed_based_model = [4157.07, 7715.55, 10730.35, 12936.86]
bathtub_approach = [5911.16, 8683.88, 10158.64, 12364.32]

# Calculate the difference between Bathtub and Processed for highlighting over/under estimation
difference = np.array(bathtub_approach) - np.array(processed_based_model)

# X-axis positions for groups
x = np.arange(len(return_periods))
width = 0.35  # Bar width

# Set font sizes for better readability
plt.rcParams.update({
    'axes.titlesize': 14,
    'axes.labelsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 10,
    'figure.titlesize': 16
})

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot bar charts
bars1 = ax.bar(x - width/2, processed_based_model, width, label='Processed Based Model', color='skyblue')
bars2 = ax.bar(x + width/2, bathtub_approach, width, label='Bathtub Approach', color='lightcoral')

# Plot the difference as a line plot to indicate over/under estimation
ax.plot(x, difference, color='green', marker='o', linestyle='--', label='Difference (Bathtub - Processed)')

# Color the line points based on positive (overestimate) or negative (underestimate)
for j in range(len(difference)):
    color = 'red' if difference[j] > 0 else 'blue'
    ax.plot(x[j], difference[j], marker='o', color=color)

# Customize plot
ax.set_title('Comparison of Flood Impact Predictions: Processed vs Bathtub Model')
ax.set_xticks(x)
ax.set_xticklabels(return_periods)
ax.set_xlabel('Return Period')
ax.set_ylabel('Predicted Flood Impact Value')
ax.legend(loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
processed_based_model = [4157.07, 7715.55, 10730.35, 12936.86]
bathtub_approach = [5911.16, 8683.88, 10158.64, 12364.32]

# Calculate the difference between Bathtub and Processed (to highlight over/underestimation)
difference = np.array(bathtub_approach) - np.array(processed_based_model)

# X-axis positions for groups
x = np.arange(len(return_periods))
width = 0.35  # Bar width

# Set font sizes for better readability
plt.rcParams.update({
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'legend.fontsize': 14,
    'figure.titlesize': 16
})

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot bar charts for absolute flooded areas
bars1 = ax.bar(x - width/2, processed_based_model, width, label='Processed Based Model', color='deepskyblue')
bars2 = ax.bar(x + width/2, bathtub_approach, width, label='Bathtub Approach', color='salmon')

# Plot filled area to highlight over/underestimation difference
# Positive values (Bathtub approach overestimation) will be filled above zero, negative values below zero
ax.fill_between(x, 0, difference, where=(difference >= 0), color='lightcoral', alpha=0.3, label='Overestimation')
ax.fill_between(x, 0, difference, where=(difference < 0), color='lightblue', alpha=0.3, label='Underestimation')

# Color the line points based on positive (overestimate) or negative (underestimate)
for j in range(len(difference)):
    color = 'red' if difference[j] > 0 else 'blue'
    ax.plot(x[j], difference[j], marker='o', color=color, markersize=8)

# Customize plot
ax.set_title('Comparison of Flooded Area Predictions: Processed vs Bathtub Approach')
ax.set_xticks(x)
ax.set_xticklabels(return_periods)
ax.set_xlabel('Return Period')
ax.set_ylabel('Flooded Area (sq km)')
ax.legend(loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Data from the table
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
processed_based_model = [4157.07, 7715.55, 10730.35, 12936.86]
bathtub_approach = [5911.16, 8683.88, 10158.64, 12364.32]

# Calculate the difference (over/underestimation)
difference = np.array(bathtub_approach) - np.array(processed_based_model)

# X-axis positions for groups
x = np.arange(len(return_periods))
width = 0.3  # Bar width

# Set font sizes for readability
plt.rcParams.update({
    'axes.titlesize': 18,
    'axes.labelsize': 14,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 15,
    'figure.titlesize': 20
})

# Custom color maps for gradient bars
cmap1 = LinearSegmentedColormap.from_list("skyblue_gradient", ["#89CFF0", "deepskyblue"])
cmap2 = LinearSegmentedColormap.from_list("salmon_gradient", ["#FFCCCB", "salmon"])

# Create the plot
fig, ax = plt.subplots(figsize=(14, 8))
fig.patch.set_facecolor('#f7f7f7')  # Set a light background for the figure

# Gradient bars for Processed Based Model and Bathtub Approach
for i in range(len(x)):
    ax.bar(x[i] - width/2, processed_based_model[i], width, label='Processed Based Model' if i == 0 else "", color=cmap1(i / len(x)))
    ax.bar(x[i] + width/2, bathtub_approach[i], width, label='Bathtub Approach' if i == 0 else "", color=cmap2(i / len(x)))

# Line plot for the difference with shading for over/underestimation
ax.plot(x, difference, color='gray', marker='o', markersize=8, linestyle='-', label='Difference (Bathtub - Processed)')
ax.fill_between(x, 0, difference, where=(difference >= 0), color='salmon', alpha=0.2)
ax.fill_between(x, 0, difference, where=(difference < 0), color='skyblue', alpha=0.2)

# Add annotations on top of each bar for exact values
for i in range(len(x)):
    ax.text(x[i] - width/2, processed_based_model[i] + 200, f"{processed_based_model[i]:,.2f}", ha='center', va='bottom', fontsize=14, color='deepskyblue')
    ax.text(x[i] + width/2, bathtub_approach[i] + 200, f"{bathtub_approach[i]:,.2f}", ha='center', va='bottom', fontsize=14, color='salmon')
    ax.text(x[i], difference[i] + (150 if difference[i] > 0 else -250), f"{difference[i]:,.2f}", ha='center', va='bottom', fontsize=14, color='gray')

# Customize plot
# ax.set_title('Flooded Area Prediction Comparison\nProcessed Based Model vs Bathtub Approach')
ax.set_xticks(x)
ax.set_xticklabels(return_periods)
ax.set_xlabel('Return Period')
ax.set_ylabel('Flooded Area (sq km)')
ax.grid(axis='y', linestyle='--', alpha=0.8)
ax.legend(loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Data from the table
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
processed_based_model = [4157.07, 7715.55, 10730.35, 12936.86]
bathtub_approach = [5911.16, 8683.88, 10158.64, 12364.32]

# Calculate the difference (over/underestimation)
difference = np.array(bathtub_approach) - np.array(processed_based_model)

# X-axis positions for groups
x = np.arange(len(return_periods))
width = 0.3  # Bar width

# Set font sizes for readability
plt.rcParams.update({
    'axes.titlesize': 18,
    'axes.labelsize': 14,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 15,
    'figure.titlesize': 20
})

# Custom color maps for gradient bars
cmap1 = LinearSegmentedColormap.from_list("skyblue_gradient", ["#89CFF0", "deepskyblue"])
cmap2 = LinearSegmentedColormap.from_list("salmon_gradient", ["#FFCCCB", "salmon"])

# Create the plot
fig, ax = plt.subplots(figsize=(14, 8))

# Gradient bars for Processed Based Model and Bathtub Approach
for i in range(len(x)):
    ax.bar(x[i] - width/2, processed_based_model[i], width, label='Processed Based Model' if i == 0 else "", color=cmap1(i / len(x)))
    ax.bar(x[i] + width/2, bathtub_approach[i], width, label='Bathtub Approach' if i == 0 else "", color=cmap2(i / len(x)))

# Line plot for the difference
ax.plot(x, difference, color='gray', marker='o', markersize=8, linestyle='-', label='Difference (Bathtub - Processed)')

# Add annotations on top of each bar for exact values
for i in range(len(x)):
    ax.text(x[i] - width/2, processed_based_model[i] + 200, f"{processed_based_model[i]:,.2f}", ha='center', va='bottom', fontsize=14, color='deepskyblue')
    ax.text(x[i] + width/2, bathtub_approach[i] + 200, f"{bathtub_approach[i]:,.2f}", ha='center', va='bottom', fontsize=14, color='salmon')
    ax.text(x[i], difference[i] + (150 if difference[i] > 0 else -250), f"{difference[i]:,.2f}", ha='center', va='bottom', fontsize=14, color='gray')

# Customize plot
ax.set_xticks(x)
ax.set_xticklabels(return_periods)
ax.set_xlabel('Return Period')
ax.set_ylabel('Flooded Area (sq km)')
ax.grid(axis='y', linestyle='--', alpha=0.8)
ax.legend(loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
return_periods = ['5 Yr', '10 Yr', '20 Yr', '50 Yr']
processed_based_model = [4157.07, 7715.55, 10730.35, 12936.86]
bathtub_approach = [5911.16, 8683.88, 10158.64, 12364.32]

# Calculate the difference (over/underestimation)
difference = np.array(bathtub_approach) - np.array(processed_based_model)

# X-axis positions for groups
x = np.arange(len(return_periods))
width = 0.3  # Bar width

# Set font sizes for readability
plt.rcParams.update({
    'axes.titlesize': 22,
    'axes.labelsize': 16,
    'xtick.labelsize': 17,
    'ytick.labelsize': 17,
    'legend.fontsize': 16,
    'figure.titlesize': 22
})

# Colors for solid bars
color_processed = "royalblue"  # Solid blue color for Processed Based Model
color_bathtub = "tomato"       # Solid red color for Bathtub Approach

# Create the plot
fig, ax = plt.subplots(figsize=(10,6))

# Solid bars for Processed Based Model and Bathtub Approach
for i in range(len(x)):
    ax.bar(x[i] - width/2, processed_based_model[i], width, label='Processed Based Model' if i == 0 else "", color=color_processed)
    ax.bar(x[i] + width/2, bathtub_approach[i], width, label='Bathtub Approach' if i == 0 else "", color=color_bathtub)

# Line plot for the difference with shading for over/underestimation
ax.plot(x, difference, color='gray', marker='o', markersize=8, linestyle='-', label='Difference (Bathtub - Processed)')
ax.fill_between(x, 0, difference, where=(difference >= 0), color='tomato', alpha=0.2, label='Overestimate')
ax.fill_between(x, 0, difference, where=(difference < 0), color='royalblue', alpha=0.2, label='Underestimate')

# Add annotations on top of each bar for exact values
for i in range(len(x)):
    ax.text(x[i] - width/2, processed_based_model[i] + 200, f"{processed_based_model[i]:,.0f}", ha='center', va='bottom', fontsize=12, color='darkblue')
    ax.text(x[i] + width/2, bathtub_approach[i] + 200, f"{bathtub_approach[i]:,.0f}", ha='center', va='bottom', fontsize=12, color='darkred')
    ax.text(x[i], difference[i] + (150 if difference[i] > 0 else -250), f"{difference[i]:,.0f}", ha='right', va='top', fontsize=12, color='gray')

# Customize plot
ax.set_xticks(x)
ax.set_xticklabels(return_periods)
ax.set_xlabel('Return Period')
ax.set_ylabel('Flooded Area (sq km)')
ax.grid(axis='y', linestyle='--', alpha=0.8)
ax.legend(loc='upper left', frameon=False)  # Remove legend box background

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Return periods
return_periods = [5, 10, 20, 50]

# Flooded area values
process_based = [4157.07, 7715.55, 10730.35, 12936.86]
bathtub = [5911.16, 8683.88, 10158.64, 12364.32]

# Create plot
plt.figure(figsize=(10, 6))
plt.plot(return_periods, process_based, linestyle='-', label='Process-based Model')
plt.plot(return_periods, bathtub, linestyle='--', label='Bathtub Approach')

# Labels and title
plt.xlabel('Return Period (Years)', fontsize=16)
plt.ylabel('Flooded Area (sq. km)', fontsize=16)
#plt.title('Flooded Area vs. Return Period', fontsize=22)
plt.legend()
plt.grid(True)
plt.xticks(return_periods)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# Original data
return_periods = np.array([5, 10, 20, 50])
process_based = np.array([4157.07, 7715.55, 10730.35, 12936.86])
bathtub = np.array([5911.16, 8683.88, 10158.64, 12364.32])

# Create smooth x-values
x_smooth = np.linspace(return_periods.min(), return_periods.max(),1000)

# Spline interpolation
process_smooth = make_interp_spline(return_periods, process_based)(x_smooth)
bathtub_smooth = make_interp_spline(return_periods, bathtub)(x_smooth)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x_smooth, process_smooth, linestyle='-', label='Process-based Model')
plt.plot(x_smooth, bathtub_smooth, linestyle='--', label='Bathtub Approach')

# Labels and title
plt.xlabel('Return Period (Years)', fontsize=12)
plt.ylabel('Flooded Area (sq. km)', fontsize=12)
plt.title('Flooded Area vs. Return Period', fontsize=14)
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Years up to 2100
years = ['2030', '2050', '2090', '2100']

# Data for SSP2-4.5 and SSP3-7.0 scenarios
main_values = {
    "SSP2-4.5": [0.27, 0.53, 1.06, 1.19],
    "SSP3-7.0": [0.28, 0.53, 1.13, 1.31]
}

lower_bounds = {
    "SSP2-4.5": [0.23, 0.45, 0.92, 1.02],
    "SSP3-7.0": [0.23, 0.46, 0.99, 1.15]
}

upper_bounds = {
    "SSP2-4.5": [0.32, 0.62, 1.26, 1.44],
    "SSP3-7.0": [0.33, 0.62, 1.35, 1.57]
}

colors = {
    "SSP2-4.5": "green",
    "SSP3-7.0": "red"
}

# Generate smooth data for plotting
smooth_years = np.linspace(2030, 2100, 500)
ssp2_45_smooth = np.interp(smooth_years, [2030, 2050, 2090, 2100], main_values["SSP2-4.5"])
ssp3_70_smooth = np.interp(smooth_years, [2030, 2050, 2090, 2100], main_values["SSP3-7.0"])

ssp2_45_lower_smooth = np.interp(smooth_years, [2030, 2050, 2090, 2100], lower_bounds["SSP2-4.5"])
ssp2_45_upper_smooth = np.interp(smooth_years, [2030, 2050, 2090, 2100], upper_bounds["SSP2-4.5"])

ssp3_70_lower_smooth = np.interp(smooth_years, [2030, 2050, 2090, 2100], lower_bounds["SSP3-7.0"])
ssp3_70_upper_smooth = np.interp(smooth_years, [2030, 2050, 2090, 2100], upper_bounds["SSP3-7.0"])

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))

# Plot SSP2-4.5 with confidence intervals
ax.plot(smooth_years, ssp2_45_smooth, label="SSP2-4.5", color=colors["SSP2-4.5"], linewidth=2)
ax.fill_between(smooth_years, ssp2_45_lower_smooth, ssp2_45_upper_smooth, color=colors["SSP2-4.5"], alpha=0.2)

# Plot SSP3-7.0 with confidence intervals
ax.plot(smooth_years, ssp3_70_smooth, label="SSP3-7.0", color=colors["SSP3-7.0"], linewidth=2)
ax.fill_between(smooth_years, ssp3_70_lower_smooth, ssp3_70_upper_smooth, color=colors["SSP3-7.0"], alpha=0.2)

# Customize plot
ax.set_xlabel("Year", fontsize=14)
ax.set_ylabel("Total Projected Values", fontsize=14)
ax.set_title("Total Projected Values under SSP2-4.5 and SSP3-7.0 with Confidence Intervals", fontsize=16)
ax.legend(loc="upper left", fontsize=12)
ax.tick_params(axis='both', which='major', labelsize=12)
ax.grid(True, linestyle="--", alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Prepare data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

df = pd.DataFrame(data)
df_sorted = df.sort_values('Avg. SVI', ascending=False)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Stacked bar plot
ax1.bar(df_sorted['County'], df_sorted['5 yr'], label='5 yr', color='skyblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['10 yr'], bottom=df_sorted['5 yr'], label='10 yr', color='steelblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['20 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'], label='20 yr', color='dodgerblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['50 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'] + df_sorted['20 yr'], label='50 yr', color='blue', alpha=0.8)

# Line plot for Avg. SVI
ax2 = ax1.twinx()
ax2.plot(df_sorted['County'], df_sorted['Avg. SVI'], label='Avg. SVI', color='orange', marker='o', linewidth=2)

# Customizing
ax1.set_ylabel('Flood-Affected Population', fontsize=14)
ax2.set_ylabel('Avg. SVI', fontsize=14, color='orange')
ax1.set_xlabel('County', fontsize=14)
ax1.set_title('Flood-Affected Population and Avg. SVI by County', fontsize=18)
ax1.legend(loc='upper right')
ax2.tick_params(axis='y', labelcolor='orange')
plt.xticks(rotation=45, fontsize=12)
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Prepare data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

df = pd.DataFrame(data)
df_sorted = df.sort_values('Avg. SVI', ascending=False)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Stacked bar plot
ax1.bar(df_sorted['County'], df_sorted['5 yr'], label='5 yr', color='skyblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['10 yr'], bottom=df_sorted['5 yr'], label='10 yr', color='steelblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['20 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'], label='20 yr', color='dodgerblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['50 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'] + df_sorted['20 yr'], label='50 yr', color='blue', alpha=0.8)

# Line plot for Avg. SVI
ax2 = ax1.twinx()
ax2.plot(df_sorted['County'], df_sorted['Avg. SVI'], label='Avg. SVI', color='orange', marker='o', linewidth=2)

# Customizing
ax1.set_ylabel('Flood-Affected Population', fontsize=14)
ax2.set_ylabel('Avg. SVI', fontsize=14, color='orange')
ax1.set_xlabel('County', fontsize=14)
ax1.set_title('Flood-Affected Population and Avg. SVI by County', fontsize=18)
ax1.legend(loc='upper left')
ax2.tick_params(axis='y', labelcolor='orange')
plt.xticks(rotation=45, fontsize=12)  # Rotate x-axis labels by 45 degrees
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Prepare data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

df = pd.DataFrame(data)
df_sorted = df.sort_values('Avg. SVI', ascending=False)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Stacked bar plot
ax1.bar(df_sorted['County'], df_sorted['5 yr'], label='5 yr', color='skyblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['10 yr'], bottom=df_sorted['5 yr'], label='10 yr', color='steelblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['20 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'], label='20 yr', color='dodgerblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['50 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'] + df_sorted['20 yr'], label='50 yr', color='blue', alpha=0.8)

# Line plot for Avg. SVI
ax2 = ax1.twinx()
ax2.plot(df_sorted['County'], df_sorted['Avg. SVI'], label='Avg. SVI', color='orange', marker='o', linewidth=2)

# Customizing
ax1.set_ylabel('Flood-Affected Population', fontsize=14)
ax2.set_ylabel('Avg. SVI', fontsize=14, color='orange')
ax1.set_xlabel('County', fontsize=14)
ax1.set_title('Flood-Affected Population and Avg. SVI by County', fontsize=18)
ax1.legend(loc='upper left')
ax2.tick_params(axis='y', labelcolor='orange')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Prepare data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

df = pd.DataFrame(data)
df_sorted = df.sort_values('Avg. SVI', ascending=False)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Stacked bar plot
ax1.bar(df_sorted['County'], df_sorted['5 yr'], label='5 yr', color='skyblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['10 yr'], bottom=df_sorted['5 yr'], label='10 yr', color='steelblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['20 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'], label='20 yr', color='dodgerblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['50 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'] + df_sorted['20 yr'], label='50 yr', color='blue', alpha=0.8)

# Line plot for Avg. SVI
ax2 = ax1.twinx()
ax2.plot(df_sorted['County'], df_sorted['Avg. SVI'], label='Avg. SVI', color='orange', marker='o', linewidth=2)

# Customizing
ax1.set_ylabel('Flood-Affected Population', fontsize=14)
ax2.set_ylabel('Avg. SVI', fontsize=14, color='orange')
ax1.set_xlabel('County', fontsize=14)
ax1.set_title('Flood-Affected Population and Avg. SVI by County', fontsize=18)
ax1.legend(loc='upper left')
ax2.tick_params(axis='y', labelcolor='orange')

# Rotate the x-axis labels explicitly
plt.xticks(rotation=45, ha='right', fontsize=12)  # Fix rotation and alignment
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Prepare data
data = {
    'County': ['Kenedy', 'Kleberg', 'Matagorda', 'Nueces', 'Refugio', 'San Patricio', 'Victoria', 'Wharton', 'Aransas', 'Bee', 
               'Brazoria', 'Calhoun', 'Jackson', 'Jim Wells', 'Willacy', 'Brooks'],
    'Avg. SVI': [0.7529, 0.762403, 0.512246, 0.503295, 0.596874, 0.606658, 0.3293, 0.3794, 0.622322, 0.668765,
                 0.5749, 0.724404, 0.550436, 0.7199, 0, 0.913826],
    '5 yr': [4, 1225, 2861, 187479, 826, 41946, 10, 0, 19420, 0, 0, 15187, 2074, 0, 0, 0],
    '10 yr': [159, 20992, 4547, 253794, 1666, 50323, 856, 44, 21308, 351, 122, 16767, 5230, 0, 0, 0],
    '20 yr': [187, 21313, 5708, 261624, 2559, 56330, 1126, 44, 21930, 590, 393, 18104, 11637, 106, 0, 1048],
    '50 yr': [190, 22962, 9904, 312028, 2753, 59083, 1126, 44, 23058, 590, 393, 21435, 11982, 106, 0, 1048]
}

df = pd.DataFrame(data)
df_sorted = df.sort_values('Avg. SVI', ascending=False)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

# Stacked bar plot
ax1.bar(df_sorted['County'], df_sorted['5 yr'], label='5 yr', color='skyblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['10 yr'], bottom=df_sorted['5 yr'], label='10 yr', color='steelblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['20 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'], label='20 yr', color='dodgerblue', alpha=0.8)
ax1.bar(df_sorted['County'], df_sorted['50 yr'], bottom=df_sorted['5 yr'] + df_sorted['10 yr'] + df_sorted['20 yr'], label='50 yr', color='blue', alpha=0.8)

# Line plot for Avg. SVI
ax2 = ax1.twinx()
ax2.plot(df_sorted['County'], df_sorted['Avg. SVI'], label='Avg. SVI', color='orange', marker='o', linewidth=2)

# Customizing
ax1.set_ylabel('Flood-Affected Population', fontsize=14)
ax2.set_ylabel('Avg. SVI', fontsize=17, color='orange')
ax1.set_xlabel('County', fontsize=17)
ax1.set_title('Flood-Affected Population and Avg. SVI by County', fontsize=18)
ax1.legend(loc='upper right')
ax2.tick_params(axis='y', labelcolor='orange')

# Rotate the x-axis labels correctly
ax1.set_xticklabels(df_sorted['County'], rotation=45, ha='right', fontsize=14)

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sahad2\AppData\Local\Temp\ipykernel_39552\1373887482.py:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_sorted['County'], rotation=45, ha='right', fontsize=14)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data based on the provided table
data = {
    'Return period': ['5 Yr', '5 Yr', '10 Yr', '10 Yr', '20 Yr', '20 Yr', '50 Yr', '50 Yr'],
    'Vulnerability': ['Flood affected', 'Flood safe', 'Flood affected', 'Flood safe', 
                      'Flood affected', 'Flood safe', 'Flood affected', 'Flood safe'],
    'School': [50.29, 49.71, 80.7, 19.3, 89.47, 10.53, 98.25, 1.75],
    'Hospital': [40.91, 59.09, 50, 50, 54.55, 45.45, 86.36, 13.64],
    'Fire and EMS': [54.84, 45.16, 75.81, 24.19, 85.48, 14.52, 93.55, 6.45],
    'National Shelter': [34.04, 65.96, 78.72, 21.28, 89.36, 10.64, 91.49, 8.51]
}

# Convert data to a DataFrame
df = pd.DataFrame(data)

# Melt the DataFrame for easier plotting with Seaborn
df_melted = df.melt(id_vars=['Return period', 'Vulnerability'], 
                    var_name='Facility', value_name='Percentage')

# Set up the color palette
palette = {'Flood affected': 'coral', 'Flood safe': 'lightgreen'}

# Create a FacetGrid plot to create a separate plot for each facility
g = sns.FacetGrid(df_melted, col="Facility", hue="Vulnerability", height=4, aspect=1, palette=palette)
g.map(sns.barplot, "Return period", "Percentage", order=["5 Yr", "10 Yr", "20 Yr", "50 Yr"], edgecolor='black')

# Add titles and legends
g.set_titles("{col_name}")
g.set_axis_labels("Return Period", "Percentage (%)")
g.add_legend(title="Vulnerability")

# Customize each subplot for visual enhancement
for ax in g.axes.flat:
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    for label in ax.get_xticklabels():
        label.set_rotation(45)
    for p in ax.patches:
        ax.annotate(f"{p.get_height():.1f}", (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 8), textcoords='offset points', fontsize=10, color='black')

# Adjust layout
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Flood Vulnerability of Critical Infrastructure Across Different Return Periods", fontsize=16)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import numpy as np

# Data for SSP2-4.5 and SSP3-7.0 only, up to the year 2100
data = {
    'Year': [2030, 2050, 2090, 2100],
    'SSP2-4.5': [0.16, 0.33, 0.68, 0.76],
    'SSP2-4.5_low': [0.12, 0.25, 0.54, 0.59],
    'SSP2-4.5_high': [0.21, 0.42, 0.88, 1.02],
    'SSP3-7.0': [0.17, 0.33, 0.75, 0.89],
    'SSP3-7.0_low': [0.12, 0.26, 0.60, 0.71],
    'SSP3-7.0_high': [0.22, 0.42, 0.97, 1.15]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Define years for interpolation and convert to a numpy array
years = np.array(df['Year'])
years_smooth = np.linspace(years.min(), years.max(), 300)  # Smooth range

# Interpolate SSP2-4.5
ssp2_4_5_smooth = make_interp_spline(years, df['SSP2-4.5'])(years_smooth)
ssp2_4_5_low_smooth = make_interp_spline(years, df['SSP2-4.5_low'])(years_smooth)
ssp2_4_5_high_smooth = make_interp_spline(years, df['SSP2-4.5_high'])(years_smooth)

# Interpolate SSP3-7.0
ssp3_7_0_smooth = make_interp_spline(years, df['SSP3-7.0'])(years_smooth)
ssp3_7_0_low_smooth = make_interp_spline(years, df['SSP3-7.0_low'])(years_smooth)
ssp3_7_0_high_smooth = make_interp_spline(years, df['SSP3-7.0_high'])(years_smooth)

# Plotting
plt.figure(figsize=(5, 5))

# Plot SSP2-4.5 with shaded uncertainty
plt.plot(years_smooth, ssp2_4_5_smooth, label='SSP2-4.5', color='green', linewidth=2)
plt.fill_between(years_smooth, ssp2_4_5_low_smooth, ssp2_4_5_high_smooth, color='green', alpha=0.3)

# Plot SSP3-7.0 with shaded uncertainty
plt.plot(years_smooth, ssp3_7_0_smooth, label='SSP3-7.0', color='red', linewidth=2)
plt.fill_between(years_smooth, ssp3_7_0_low_smooth, ssp3_7_0_high_smooth, color='red', alpha=0.3)

# Customize plot
plt.title('Port Mansfield', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sea Level Rise (m)', fontsize=14)
plt.legend(loc='upper left', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import numpy as np

# Updated data for SSP2-4.5 and SSP3-7.0 only, up to the year 2100
data = {
    'Year': [2030, 2050, 2090, 2100],
    'SSP2-4.5': [0.19, 0.37, 0.77, 0.86],
    'SSP2-4.5_low': [0.14, 0.29, 0.62, 0.68],
    'SSP2-4.5_high': [0.24, 0.47, 0.98, 1.12],
    'SSP3-7.0': [0.19, 0.38, 0.84, 0.99],
    'SSP3-7.0_low': [0.14, 0.30, 0.69, 0.81],
    'SSP3-7.0_high': [0.24, 0.47, 1.06, 1.25]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Define years for interpolation and convert to a numpy array
years = np.array(df['Year'])
years_smooth = np.linspace(years.min(), years.max(), 300)  # Smooth range

# Interpolate SSP2-4.5
ssp2_4_5_smooth = make_interp_spline(years, df['SSP2-4.5'])(years_smooth)
ssp2_4_5_low_smooth = make_interp_spline(years, df['SSP2-4.5_low'])(years_smooth)
ssp2_4_5_high_smooth = make_interp_spline(years, df['SSP2-4.5_high'])(years_smooth)

# Interpolate SSP3-7.0
ssp3_7_0_smooth = make_interp_spline(years, df['SSP3-7.0'])(years_smooth)
ssp3_7_0_low_smooth = make_interp_spline(years, df['SSP3-7.0_low'])(years_smooth)
ssp3_7_0_high_smooth = make_interp_spline(years, df['SSP3-7.0_high'])(years_smooth)

# Plotting
plt.figure(figsize=(5, 5))

# Plot SSP2-4.5 with shaded uncertainty
plt.plot(years_smooth, ssp2_4_5_smooth, label='SSP2-4.5', color='green', linewidth=2)
plt.fill_between(years_smooth, ssp2_4_5_low_smooth, ssp2_4_5_high_smooth, color='green', alpha=0.3)

# Plot SSP3-7.0 with shaded uncertainty
plt.plot(years_smooth, ssp3_7_0_smooth, label='SSP3-7.0', color='red', linewidth=2)
plt.fill_between(years_smooth, ssp3_7_0_low_smooth, ssp3_7_0_high_smooth, color='red', alpha=0.3)

# Customize plot
plt.title('Mid Point', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sea Level Rise (m)', fontsize=14)
plt.legend(loc='upper left', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
import numpy as np

# Updated data for SSP2-4.5 and SSP3-7.0 only, up to the year 2100
data = {
    'Year': [2030, 2050, 2090, 2100],
    'SSP2-4.5': [0.27, 0.53, 1.06, 1.19],
    'SSP2-4.5_low': [0.23, 0.45, 0.92, 1.02],
    'SSP2-4.5_high': [0.32, 0.62, 1.26, 1.44],
    'SSP3-7.0': [0.28, 0.53, 1.13, 1.31],
    'SSP3-7.0_low': [0.23, 0.46, 0.99, 1.15],
    'SSP3-7.0_high': [0.33, 0.62, 1.35, 1.57]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Define years for interpolation and convert to a numpy array
years = np.array(df['Year'])
years_smooth = np.linspace(years.min(), years.max(), 300)  # Smooth range

# Interpolate SSP2-4.5
ssp2_4_5_smooth = make_interp_spline(years, df['SSP2-4.5'])(years_smooth)
ssp2_4_5_low_smooth = make_interp_spline(years, df['SSP2-4.5_low'])(years_smooth)
ssp2_4_5_high_smooth = make_interp_spline(years, df['SSP2-4.5_high'])(years_smooth)

# Interpolate SSP3-7.0
ssp3_7_0_smooth = make_interp_spline(years, df['SSP3-7.0'])(years_smooth)
ssp3_7_0_low_smooth = make_interp_spline(years, df['SSP3-7.0_low'])(years_smooth)
ssp3_7_0_high_smooth = make_interp_spline(years, df['SSP3-7.0_high'])(years_smooth)

# Plotting
plt.figure(figsize=(5, 5))

# Plot SSP2-4.5 with shaded uncertainty
plt.plot(years_smooth, ssp2_4_5_smooth, label='SSP2-4.5', color='green', linewidth=2)
plt.fill_between(years_smooth, ssp2_4_5_low_smooth, ssp2_4_5_high_smooth, color='green', alpha=0.3)

# Plot SSP3-7.0 with shaded uncertainty
plt.plot(years_smooth, ssp3_7_0_smooth, label='SSP3-7.0', color='red', linewidth=2)
plt.fill_between(years_smooth, ssp3_7_0_low_smooth, ssp3_7_0_high_smooth, color='red', alpha=0.3)

# Customize plot
plt.title('Free Port', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sea Level Rise (m)', fontsize=14)
plt.legend(loc='upper left', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Show plot
plt.show()
